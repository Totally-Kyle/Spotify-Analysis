# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import the data from the csv and store it in the raw_data variable
raw_data = pd.read_csv("/Users/sa24/Desktop/Spotify TLAB/Spotify-Analysis/Raw data/train.csv")

# %%
#see the types for all the columsn in raw_data
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28362 entries, 0 to 28361
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                28362 non-null  int64
#  1   artist_name               28362 non-null  object
#  2   track_name                28362 non-null  object
#  3   release_date              28362 non-null  int64
#  4   genre                     28362 non-null  object
#  5   lyrics                    28362 non-null  object
#  6   len                       28362 non-null  int64
#  7   dating                    28362 non-null  float64
#  8   violence                  28362 non-null  float64
#  9   world/life                28362 non-null  float64
#  10  night/time                28362 non-null  float64
#  11  shake the audience        28362 non-null  float64
#  12  family/gospel             28362 non-null  float64
# ...

# %%
#drop all the columns that have an object type and Unnamed columms
drop_columns = ["Unnamed: 0", "release_date", "track_name", "lyrics", "artist_name", "topic", "genre"]
cleaned_data = raw_data.drop(drop_columns, axis= 1)
cleaned_data.head()
# Out:
#    len    dating  violence  world/life  night/time  shake the audience  \
# 0   95  0.000598  0.063746    0.000598    0.000598            0.000598
# 1   51  0.035537  0.096777    0.443435    0.001284            0.001284
# 2   24  0.002770  0.002770    0.002770    0.002770            0.002770
# 3   54  0.048249  0.001548    0.001548    0.001548            0.021500
# 4   48  0.001350  0.001350    0.417772    0.001350            0.001350
#
#    family/gospel  romantic  communication   obscene     music  \
# 0       0.048857  0.017104       0.263751  0.000598  0.039288
# 1       0.027007  0.001284       0.001284  0.001284  0.118034
# 2       0.002770  0.158564       0.250668  0.002770  0.323794
# 3       0.001548  0.411536       0.001548  0.001548  0.001548
# 4       0.001350  0.463430       0.001350  0.001350  0.001350
#
#    movement/places  light/visual perceptions  family/spiritual   sadness  \
# 0         0.000598                  0.000598          0.000598  0.380299
# ...

# %%
#Save transformed data to a cvs file
cleaned_data.to_csv("Cleaned Data.csv", index= False)
